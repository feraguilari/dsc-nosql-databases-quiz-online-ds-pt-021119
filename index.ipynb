# %% [markdown]
# # NoSQL Databases - Quiz
#
#
# ## Introduction
#
# In this lesson, we'll try our luck with some common open-ended interview questions about NoSQL databases.
#
#
# ## Question 1
#
# What is the difference between a NoSQL and a SQL database?  Which is better?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# SQl uses structured query language for defining and manipulating data, while NoSQL has dynamic schema for unstructured data, and data is stored in many ways: it can be column-oriented, document-oriented, graph-based or organized as a KeyValue store.<br>
#
# Teh fitess depends on the kind of data that is going to be stored in the database. SQl is better for is a good choice for data with a predefined structure and set schemas. NoSQL databases have a dynamic schema that is much better suited for big data as flexibility is an important requirement.
#
#
#
# ## Question 2
#
# Describe a situation where a NoSQL database might be a better choice than a relational database, and explain your reasoning.
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# A database for content management sites is a good example where NoSQL would perform better than SQL since it may be requiered to store documents with different properties, users, interactions, etc.
#
#
#
#
#
#
# ## Question 3
#
# How does MongoDB work? How is it different from a relational database?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# In MongoDB, the data objects are stored as separate documents inside a collection — instead of storing the data into the columns and rows of a traditional relational database.
#
#
#
#
#
#
#
#
# ## Question 4
#
# What is fault tolerance, and what does it have to do with Resilient Distributed Datasets?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# Fault tolerance is the property that enables a system to continue operating properly in the event of the failure of (or one or more faults within) some of its components. Resilient Distributed Databases are stored in different servers with backups in other servers, so if a server is to fail, the backup kicks in.
#
#
#
#
#
#
#
#
# ## Question 5
#
# What is MapReduce? How is it related to Hadoop?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________<br>
# Queries are performed simultaneously in each of the servers containing the data and then aggregated in th emain server to deliver a final result.
#
#
# ## Summary
#
#
# In this lesson, we reviewed some common NoSQL interview questions.
